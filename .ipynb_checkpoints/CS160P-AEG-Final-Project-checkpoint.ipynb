# %% [markdown]
# <h1>Machine Learning Final Project Automated Essay Scoring System</h1>

# %% [markdown]
# <p>Assessment in the Education system plays a significant role in judging student
# performance. The present evaluation system is through human assessment. As
# the number of teachers' student ratio is gradually increasing, the manual
# evaluation process becomes complicated. The drawback of manual evaluation
# is that it is time-consuming, lacks reliability, and many more. This connection
# online examination system evolved as an alternative tool for pen and
# paper-based methods.</p>

# %% [markdown]
# <h3>Requirements:</h3>

# %% [markdown]
# <ol>
#     <li>
#         Choose any machine learning algorithm to create your own automated essay scoring using the system
#         <br/>
#     </li>
#     <li>
#         The quality of an essay is affected by the following four primary dimensions:
#         topic relevance, organization and coherence, word usage and sentence
#         complexity, and grammar and mechanics. You may use the framework below
#         to implement your model but you are allowed to enhance.
#     </li>
#     <li>
#         Use the dataset from the Kaggle ASAP competition.
#         You can download the data from the link below. https://www.kaggle.com/c/asap-aes/data
#         <br/>
#         <h4>Kaggle ASAP background:</h4>
#         <br/>
#         The Hewlett Foundation has provided a set of high school student essays
#         along with scores generated by human expert graders. The initial data
#         was released in 2012 as part of a Kaggle competition to produce an
#         automated student assessment algorithm to closely match the human
#         scores. Scores are evaluated with the quadratic weighted kappa error
#         metric, which measures the agreement between two raters.
#         <br/>
#         Since then, a few teams have published their attempts to match or
#         improve on the original challenge. Initial success was somewhat
#         disappointing as the Kappa scores were around 0.5, but improved
#         significantly by incorporating modern NLP with neural networks.
#         <br/>
#     </li>
#     <li>
#         Project Presentation: 15 minutes only (October 29, 3, 4 and 5)
#         <br/>
#     </li>
# <ol>

# %% [markdown]
# ![typical-aeg-system.png](attachment:typical-aeg-system.png)

# %%
#Initial Imports
import os
import pandas as pd
import numpy as np
import seaborn as sns
from nltk.corpus import stopwords
import re
from matplotlib import pyplot as plt
from gensim.models import Word2Vec

# %%
#Necessary Files for NLTK
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\giost\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\giost\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Declaring Variables
datasetFolder = './data/'
outputFolder = './'

#This implementation of an automated essay grader will utilize the training_set_rel3.tsv file containing all eight essay sets
#The predictor value for this automated essay grader will be domain1_score
#The main metric to gauge the effectiveness of this grader will be kappa score


X = pd.read_csv(os.path.join(datasetFolder, 'training_set_rel3.tsv'), sep='\t', encoding='ISO-8859-1')
data = X
y = X['domain1_score']
X = X.dropna(axis=1)
X = X.drop(columns=['rater1_domain1', 'rater2_domain1'])
#dropping unecessary domain rater columns

# %%
#Initial insights for the dataset
X.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    domain1_score
# 0              8
# 1              9
# 2              7
# 3             10
# 4              8

# %%
X.describe()
# Out:
#            essay_id     essay_set  domain1_score
# count  12976.000000  12976.000000   12976.000000
# mean   10295.395808      4.179485       6.800247
# std     6309.074105      2.136913       8.970705
# min        1.000000      1.000000       0.000000
# 25%     4438.750000      2.000000       2.000000
# 50%    10044.500000      4.000000       3.000000
# 75%    15681.250000      6.000000       8.000000
# max    21633.000000      8.000000      60.000000

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12976 entries, 0 to 12975
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   essay_id       12976 non-null  int64
#  1   essay_set      12976 non-null  int64
#  2   essay          12976 non-null  object
#  3   domain1_score  12976 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 405.6+ KB

# %%
X.groupby('essay_set').agg('count').plot.bar(y='essay', rot=0, legend=False)
plt.title('Essay count by topic #')
plt.ylabel('Count')
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x='domain1_score', data=X)
# Out:
# <AxesSubplot: xlabel='domain1_score', ylabel='count'>

# %%
sns.distplot(X['domain1_score'])
# Out:
# C:\Users\giost\AppData\Local\Temp\ipykernel_21120\3862004471.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X['domain1_score'])
# <AxesSubplot: xlabel='domain1_score', ylabel='Density'>

# %%
# Count characters and words for each essay
X['word_count'] = X['essay'].str.strip().str.split().str.len()

# %%
X.hist(column='word_count', by='essay_set', bins=25, sharey=True, sharex=True, layout=(2, 4), figsize=(7,4), rot=0) 
plt.suptitle('Word count by topic #')
plt.xlabel('Number of words')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
topic_number = 0
fig, ax = plt.subplots(4,2, figsize=(8,10))
for i in range(4):
    for j in range(2):
        topic_number += 1
        sns.violinplot(x='domain1_score', y='word_count', data=X[X['essay_set'] == topic_number], ax=ax[i,j])
        ax[i,j].set_title('Topic %i' % topic_number)
ax[3,0].locator_params(nbins=10)
ax[3,1].locator_params(nbins=10)
plt.suptitle('Word count by score')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
topic_number = 0
fig, ax = plt.subplots(4,2, figsize=(9,9), sharey=False)
for i in range(4):
    for j in range(2):
        topic_number += 1
        X[X['essay_set'] == topic_number]\
            .groupby('domain1_score')['essay_id']\
            .agg('count')\
            .plot.bar(ax=ax[i, j], rot=0)
        ax[i,j].set_title('Topic %i' % topic_number)
ax[3,0].locator_params(nbins=10)
ax[3,1].locator_params(nbins=10)
plt.suptitle('Histograms of essay scores')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# %matplotlib inline
X.boxplot(column = 'domain1_score', by = 'essay_set', figsize = (10,10))
# Out:
# <AxesSubplot:title={'center':'domain1_score'}, xlabel='essay_set'>

# %%
sns.scatterplot(data=X, x="domain1_score", y="essay_set")
# Out:
# <AxesSubplot:xlabel='domain1_score', ylabel='essay_set'>

# %% [markdown]
# It can be seen in this scatter plot that essay sets 8 and 7 have significantly higher domain1_scores (culminated scores between the different human essay graders) than other essay sets.

# %%
#converting the essay data into a wordlist while also filtering out unecessary stop words
def convertEssayToWordlist(essay, filterStopwords):
    essay = re.sub("[^a-zA-Z]", " ", essay)
    words = essay.lower().split()
    if filterStopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

#main tokenization process with some preprocesing
def convertEssayToSentences(essay, filterStopwords):
    tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    uncleanSentences = tokenizer.tokenize(essay.strip())
    sentences = []
    for uncleanSentence in uncleanSentences:
        if len(uncleanSentence) > 0:
            sentences.append(convertEssayToWordlist(uncleanSentence, filterStopwords))
    return sentences

#Feature vectors will be made from words in wordlist
def createFeatureVector(words, model, featureCount):
    featureVectors = np.zeros((featureCount,),dtype="float32")
    wordCount = 0.
    indexToKey = set(model.wv.index_to_key)
    for word in words:
        if word in indexToKey:
            wordCount += 1
            featureVectors = np.add(featureVectors,model.wv[word])        
    featureVectors = np.divide(featureVectors,wordCount)
    return featureVectors

#main function that will allow for word vectors to be usable by the word2Vec model
def averageFeatureVectors(essays, model, featureCount):
    ctr1 = 0
    featureVectors = np.zeros((len(essays),featureCount),dtype="float32")
    for essay in essays:
        featureVectors[ctr1] = createFeatureVector(essay, model, featureCount)
        ctr1 = ctr1 + 1
    return featureVectors

# %%
from keras.layers import Embedding, LSTM, Dense, Dropout, Lambda, Flatten
from keras.models import Sequential, load_model, model_from_config
import keras.backend as K

def defineModel():
    model = Sequential()
    model.add(LSTM(300, dropout=0.4, recurrent_dropout=0.4, input_shape=[1, 300], return_sequences=True))
    model.add(LSTM(64, recurrent_dropout=0.4))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='relu'))

    model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['mae'])
    model.summary()

    return model

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import cohen_kappa_score


kFoldSplits = KFold(n_splits=5, shuffle=True)
results = []

count = 1
for trainKfold, testKfold in kFoldSplits.split(X):
    print("\n***Fold Number {}***\n".format(count))
    X_test, X_train, y_test, y_train = X.iloc[testKfold], X.iloc[trainKfold], y.iloc[testKfold], y.iloc[trainKfold]
    
    essaysTrain = X_train['essay']
    essaysTest = X_test['essay']
    
    sentences = []
    
    #Compiling training essays
    for essay in essaysTrain:
            sentences += convertEssayToSentences(essay, filterStopwords = True)
            
    #Parameters for the model
    featureCount = 300 
    minWordCount = 40
    workerCount = 4
    context = 10
    downsampling = 1e-3

    print("***Starting Model Training***")
    model = Word2Vec(sentences, workers=workerCount, vector_size=featureCount, min_count = minWordCount, window = context, sample = downsampling)

    model.init_sims(replace=True)
    model.wv.save_word2vec_format('word2vecmodel.bin', binary=True)

    filteredEssaysTrain = []
    
    #Creating training and testing word vectors
    for essay in essaysTrain:
        filteredEssaysTrain.append(convertEssayToWordlist(essay, filterStopwords=True))
    trainDataVecs = averageFeatureVectors(filteredEssaysTrain, model, featureCount)
    
    filteredEssaysTest = []
    for essay in essaysTest:
        filteredEssaysTest.append(convertEssayToWordlist(essay, filterStopwords=True))
    testDataVecs = averageFeatureVectors(filteredEssaysTest, model, featureCount)
    
    trainDataVecs = np.array(trainDataVecs)
    testDataVecs = np.array(testDataVecs)
    
    #Reshaping train and test vectors for use in the lstmModel
    trainDataVecs = np.reshape(trainDataVecs, (trainDataVecs.shape[0], 1, trainDataVecs.shape[1]))
    testDataVecs = np.reshape(testDataVecs, (testDataVecs.shape[0], 1, testDataVecs.shape[1]))
    
    lstmModel = defineModel()
    lstmModel.fit(trainDataVecs, y_train, batch_size=64, epochs=50)
    y_pred = lstmModel.predict(testDataVecs)
    
    #Rounding off y_pred
    y_pred = np.around(y_pred)
    
    #This is the main evaluation metric (Quadratic mean averaged Kappa)
    #The original attempt for previous AEG systems attempts from other developers was around 0.5
    #Best attempt for the original competition from other developers was around 0.8
    
    result = cohen_kappa_score(y_test.values,y_pred,weights='quadratic')
    print("=== Kappa Score = {}===".format(result))
    results.append(result)

    count += 1
# Out:
# ***Fold Number 1***
#
# ***Starting Model Training***
# C:\Users\Nasha\AppData\Local\Temp\ipykernel_4852\3801135714.py:33: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   model.init_sims(replace=True)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 300)            721200
#
#  lstm_1 (LSTM)               (None, 64)                93440
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 163/163 [==============================] - 5s 13ms/step - loss: 65.1577 - mae: 4.3447
# Epoch 2/50
# 163/163 [==============================] - 2s 13ms/step - loss: 40.0530 - mae: 3.5462
# Epoch 3/50
# 163/163 [==============================] - 2s 14ms/step - loss: 33.7406 - mae: 3.4775
# Epoch 4/50
# 163/163 [==============================] - 2s 13ms/step - loss: 30.0537 - mae: 3.3312
# Epoch 5/50
# 163/163 [==============================] - 2s 13ms/step - loss: 27.7366 - mae: 3.1751
# Epoch 6/50
# 163/163 [==============================] - 2s 13ms/step - loss: 26.5542 - mae: 3.0059
# Epoch 7/50
# 163/163 [==============================] - 2s 13ms/step - loss: 24.3221 - mae: 2.8455
# Epoch 8/50
# 163/163 [==============================] - 2s 13ms/step - loss: 20.5276 - mae: 2.6212
# Epoch 9/50
# 163/163 [==============================] - 2s 13ms/step - loss: 18.5060 - mae: 2.4391
# Epoch 10/50
# 163/163 [==============================] - 2s 13ms/step - loss: 16.0876 - mae: 2.2897
# Epoch 11/50
# 163/163 [==============================] - 2s 13ms/step - loss: 14.9825 - mae: 2.2080
# Epoch 12/50
# 163/163 [==============================] - 2s 14ms/step - loss: 14.3510 - mae: 2.1645
# Epoch 13/50
# 163/163 [==============================] - 2s 13ms/step - loss: 13.6564 - mae: 2.1017
# Epoch 14/50
# 163/163 [==============================] - 2s 13ms/step - loss: 12.7712 - mae: 2.0303
# Epoch 15/50
# 163/163 [==============================] - 2s 13ms/step - loss: 12.7258 - mae: 2.0073
# Epoch 16/50
# 163/163 [==============================] - 2s 13ms/step - loss: 12.4719 - mae: 1.9781
# Epoch 17/50
# 163/163 [==============================] - 2s 14ms/step - loss: 12.4386 - mae: 1.9605
# Epoch 18/50
# 163/163 [==============================] - 2s 14ms/step - loss: 11.6580 - mae: 1.9083
# Epoch 19/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.0440 - mae: 1.8641
# Epoch 20/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.3383 - mae: 1.8603
# Epoch 21/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.7903 - mae: 1.8341
# Epoch 22/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.5298 - mae: 1.8237
# Epoch 23/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.8574 - mae: 1.8321
# Epoch 24/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.0966 - mae: 1.7708
# Epoch 25/50
# 163/163 [==============================] - 2s 14ms/step - loss: 10.2164 - mae: 1.7667
# Epoch 26/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.2513 - mae: 1.7601
# Epoch 27/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.6795 - mae: 1.7385
# Epoch 28/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.8332 - mae: 1.7278
# Epoch 29/50
# 163/163 [==============================] - 2s 14ms/step - loss: 9.9660 - mae: 1.7337
# Epoch 30/50
# 163/163 [==============================] - 2s 14ms/step - loss: 9.3375 - mae: 1.7060
# Epoch 31/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.5550 - mae: 1.7136
# Epoch 32/50
# 163/163 [==============================] - 2s 14ms/step - loss: 8.8417 - mae: 1.6720
# Epoch 33/50
# 163/163 [==============================] - 2s 14ms/step - loss: 9.7433 - mae: 1.7348
# Epoch 34/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.1701 - mae: 1.6871
# Epoch 35/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.1552 - mae: 1.6978
# Epoch 36/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.0301 - mae: 1.6781
# Epoch 37/50
# 163/163 [==============================] - 2s 14ms/step - loss: 8.8495 - mae: 1.6610
# Epoch 38/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.9633 - mae: 1.6572
# Epoch 39/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.6837 - mae: 1.6583
# Epoch 40/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.8999 - mae: 1.6663
# Epoch 41/50
# 163/163 [==============================] - 3s 16ms/step - loss: 8.6486 - mae: 1.6473
# Epoch 42/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.3753 - mae: 1.6287
# Epoch 43/50
# 163/163 [==============================] - 2s 14ms/step - loss: 8.4374 - mae: 1.6367
# Epoch 44/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.2076 - mae: 1.6091
# Epoch 45/50
# 163/163 [==============================] - 2s 12ms/step - loss: 8.3414 - mae: 1.6093
# Epoch 46/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.1560 - mae: 1.6060
# Epoch 47/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.2117 - mae: 1.6117
# Epoch 48/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.1469 - mae: 1.6061
# Epoch 49/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.1778 - mae: 1.6092
# Epoch 50/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.4332 - mae: 1.6118
# 82/82 [==============================] - 1s 3ms/step
# === Kappa Score = 0.9560030007588868===
#
# ***Fold Number 2***
#
# ***Starting Model Training***
# C:\Users\Nasha\AppData\Local\Temp\ipykernel_4852\3801135714.py:33: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   model.init_sims(replace=True)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 1, 300)            721200
#
#  lstm_3 (LSTM)               (None, 64)                93440
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 163/163 [==============================] - 5s 12ms/step - loss: 62.7689 - mae: 4.3158
# Epoch 2/50
# 163/163 [==============================] - 2s 12ms/step - loss: 39.4472 - mae: 3.5933
# Epoch 3/50
# 163/163 [==============================] - 2s 12ms/step - loss: 32.9089 - mae: 3.4522
# Epoch 4/50
# 163/163 [==============================] - 2s 13ms/step - loss: 30.2949 - mae: 3.3683
# Epoch 5/50
# 163/163 [==============================] - 2s 13ms/step - loss: 27.8946 - mae: 3.1910
# Epoch 6/50
# 163/163 [==============================] - 2s 13ms/step - loss: 26.2109 - mae: 3.0133
# Epoch 7/50
# 163/163 [==============================] - 2s 12ms/step - loss: 24.9275 - mae: 2.8739
# Epoch 8/50
# 163/163 [==============================] - 2s 12ms/step - loss: 21.3133 - mae: 2.6281
# Epoch 9/50
# 163/163 [==============================] - 2s 12ms/step - loss: 18.8034 - mae: 2.4680
# Epoch 10/50
# 163/163 [==============================] - 2s 12ms/step - loss: 16.2733 - mae: 2.3061
# Epoch 11/50
# 163/163 [==============================] - 2s 13ms/step - loss: 15.6287 - mae: 2.2443
# Epoch 12/50
# 163/163 [==============================] - 2s 14ms/step - loss: 14.8333 - mae: 2.1828
# Epoch 13/50
# 163/163 [==============================] - 2s 14ms/step - loss: 14.1112 - mae: 2.1188
# Epoch 14/50
# 163/163 [==============================] - 2s 14ms/step - loss: 13.8093 - mae: 2.0868
# Epoch 15/50
# 163/163 [==============================] - 2s 14ms/step - loss: 13.1408 - mae: 2.0487
# Epoch 16/50
# 163/163 [==============================] - 2s 13ms/step - loss: 13.0353 - mae: 2.0212
# Epoch 17/50
# 163/163 [==============================] - 2s 13ms/step - loss: 12.6130 - mae: 1.9979
# Epoch 18/50
# 163/163 [==============================] - 2s 13ms/step - loss: 12.1570 - mae: 1.9478
# Epoch 19/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.8059 - mae: 1.9161
# Epoch 20/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.4988 - mae: 1.8899
# Epoch 21/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.5467 - mae: 1.8905
# Epoch 22/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.7970 - mae: 1.8376
# Epoch 23/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.2098 - mae: 1.8544
# Epoch 24/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.3382 - mae: 1.7841
# Epoch 25/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.3592 - mae: 1.8055
# Epoch 26/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.5008 - mae: 1.7771
# Epoch 27/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.6283 - mae: 1.7838
# Epoch 28/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.1065 - mae: 1.7591
# Epoch 29/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.5133 - mae: 1.7853
# Epoch 30/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.9605 - mae: 1.7549
# Epoch 31/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.0924 - mae: 1.7635
# Epoch 32/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.7282 - mae: 1.7270
# Epoch 33/50
# 163/163 [==============================] - 2s 12ms/step - loss: 9.5846 - mae: 1.7204
# Epoch 34/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.9548 - mae: 1.7373
# Epoch 35/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.9508 - mae: 1.6779
# Epoch 36/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.7433 - mae: 1.7270
# Epoch 37/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.2917 - mae: 1.7031
# Epoch 38/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.2562 - mae: 1.6697
# Epoch 39/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.2913 - mae: 1.6834
# Epoch 40/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.4431 - mae: 1.7060
# Epoch 41/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.1484 - mae: 1.6724
# Epoch 42/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.9172 - mae: 1.6778
# Epoch 43/50
# 163/163 [==============================] - 2s 12ms/step - loss: 8.6708 - mae: 1.6532
# Epoch 44/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.2800 - mae: 1.6703
# Epoch 45/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.0144 - mae: 1.6698
# Epoch 46/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.7920 - mae: 1.6617
# Epoch 47/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.6210 - mae: 1.6364
# Epoch 48/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.7332 - mae: 1.6428
# Epoch 49/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.7050 - mae: 1.6362
# Epoch 50/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.6243 - mae: 1.6168
# 82/82 [==============================] - 0s 3ms/step
# === Kappa Score = 0.9589206364961702===
#
# ***Fold Number 3***
#
# ***Starting Model Training***
# C:\Users\Nasha\AppData\Local\Temp\ipykernel_4852\3801135714.py:33: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   model.init_sims(replace=True)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 1, 300)            721200
#
#  lstm_5 (LSTM)               (None, 64)                93440
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 163/163 [==============================] - 5s 14ms/step - loss: 65.0774 - mae: 4.3868
# Epoch 2/50
# 163/163 [==============================] - 3s 17ms/step - loss: 40.9909 - mae: 3.6285
# Epoch 3/50
# 163/163 [==============================] - 3s 16ms/step - loss: 34.4085 - mae: 3.4989
# Epoch 4/50
# 163/163 [==============================] - 2s 14ms/step - loss: 30.6411 - mae: 3.4036
# Epoch 5/50
# 163/163 [==============================] - 2s 15ms/step - loss: 28.9280 - mae: 3.2376
# Epoch 6/50
# 163/163 [==============================] - 2s 14ms/step - loss: 26.4344 - mae: 3.0444
# Epoch 7/50
# 163/163 [==============================] - 3s 16ms/step - loss: 24.9818 - mae: 2.8905
# Epoch 8/50
# 163/163 [==============================] - 2s 15ms/step - loss: 21.0243 - mae: 2.6663
# Epoch 9/50
# 163/163 [==============================] - 2s 15ms/step - loss: 18.6800 - mae: 2.4728
# Epoch 10/50
# 163/163 [==============================] - 2s 14ms/step - loss: 16.8744 - mae: 2.3258
# Epoch 11/50
# 163/163 [==============================] - 2s 14ms/step - loss: 15.1589 - mae: 2.2371
# Epoch 12/50
# 163/163 [==============================] - 2s 14ms/step - loss: 14.7621 - mae: 2.1690
# Epoch 13/50
# 163/163 [==============================] - 2s 14ms/step - loss: 14.3702 - mae: 2.1432
# Epoch 14/50
# 163/163 [==============================] - 2s 14ms/step - loss: 14.2199 - mae: 2.1021
# Epoch 15/50
# 163/163 [==============================] - 3s 16ms/step - loss: 13.1114 - mae: 2.0448
# Epoch 16/50
# 163/163 [==============================] - 2s 15ms/step - loss: 13.3556 - mae: 2.0530
# Epoch 17/50
# 163/163 [==============================] - 2s 14ms/step - loss: 12.4073 - mae: 1.9850
# Epoch 18/50
# 163/163 [==============================] - 2s 14ms/step - loss: 12.2832 - mae: 1.9495
# Epoch 19/50
# 163/163 [==============================] - 2s 14ms/step - loss: 11.3148 - mae: 1.9038
# Epoch 20/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.4524 - mae: 1.8876
# Epoch 21/50
# 163/163 [==============================] - 3s 17ms/step - loss: 11.3295 - mae: 1.8746
# Epoch 22/50
# 163/163 [==============================] - 3s 16ms/step - loss: 11.1545 - mae: 1.8547
# Epoch 23/50
# 163/163 [==============================] - 4s 22ms/step - loss: 10.8290 - mae: 1.8348
# Epoch 24/50
# 163/163 [==============================] - 3s 17ms/step - loss: 10.5764 - mae: 1.8094
# Epoch 25/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.3106 - mae: 1.8018
# Epoch 26/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.1836 - mae: 1.7827
# Epoch 27/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.7981 - mae: 1.7517
# Epoch 28/50
# 163/163 [==============================] - 2s 14ms/step - loss: 10.3487 - mae: 1.8106
# Epoch 29/50
# 163/163 [==============================] - 2s 14ms/step - loss: 10.3149 - mae: 1.8053
# Epoch 30/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.0439 - mae: 1.7619
# Epoch 31/50
# 163/163 [==============================] - 2s 14ms/step - loss: 9.4624 - mae: 1.7406
# Epoch 32/50
# 163/163 [==============================] - 3s 16ms/step - loss: 9.7091 - mae: 1.7504
# Epoch 33/50
# 163/163 [==============================] - 3s 16ms/step - loss: 9.5260 - mae: 1.7322
# Epoch 34/50
# 163/163 [==============================] - 2s 14ms/step - loss: 9.4009 - mae: 1.7301
# Epoch 35/50
# 163/163 [==============================] - 3s 16ms/step - loss: 9.7547 - mae: 1.7262
# Epoch 36/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.3179 - mae: 1.7288
# Epoch 37/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.2133 - mae: 1.7105
# Epoch 38/50
# 163/163 [==============================] - 2s 14ms/step - loss: 9.5587 - mae: 1.7301
# Epoch 39/50
# 163/163 [==============================] - 2s 14ms/step - loss: 9.2340 - mae: 1.7061
# Epoch 40/50
# 163/163 [==============================] - 2s 14ms/step - loss: 9.0820 - mae: 1.7003
# Epoch 41/50
# 163/163 [==============================] - 2s 14ms/step - loss: 8.9774 - mae: 1.7037
# Epoch 42/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.2257 - mae: 1.7121
# Epoch 43/50
# 163/163 [==============================] - 2s 14ms/step - loss: 9.0786 - mae: 1.6880
# Epoch 44/50
# 163/163 [==============================] - 3s 21ms/step - loss: 8.7258 - mae: 1.6790
# Epoch 45/50
# 163/163 [==============================] - 3s 18ms/step - loss: 8.9669 - mae: 1.6897
# Epoch 46/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.6028 - mae: 1.6611
# Epoch 47/50
# 163/163 [==============================] - 2s 14ms/step - loss: 8.7471 - mae: 1.6721
# Epoch 48/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.6816 - mae: 1.6590
# Epoch 49/50
# 163/163 [==============================] - 2s 14ms/step - loss: 9.1950 - mae: 1.6959
# Epoch 50/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.8983 - mae: 1.6760
# 82/82 [==============================] - 1s 4ms/step
# === Kappa Score = 0.9620655235047979===
#
# ***Fold Number 4***
#
# ***Starting Model Training***
# C:\Users\Nasha\AppData\Local\Temp\ipykernel_4852\3801135714.py:33: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   model.init_sims(replace=True)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 1, 300)            721200
#
#  lstm_7 (LSTM)               (None, 64)                93440
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 163/163 [==============================] - 5s 12ms/step - loss: 63.7122 - mae: 4.3356
# Epoch 2/50
# 163/163 [==============================] - 2s 12ms/step - loss: 39.6975 - mae: 3.5478
# Epoch 3/50
# 163/163 [==============================] - 2s 12ms/step - loss: 33.0218 - mae: 3.4335
# Epoch 4/50
# 163/163 [==============================] - 2s 12ms/step - loss: 30.8958 - mae: 3.3817
# Epoch 5/50
# 163/163 [==============================] - 2s 12ms/step - loss: 28.7724 - mae: 3.2585
# Epoch 6/50
# 163/163 [==============================] - 2s 12ms/step - loss: 27.5600 - mae: 3.1043
# Epoch 7/50
# 163/163 [==============================] - 2s 12ms/step - loss: 25.4682 - mae: 2.9541
# Epoch 8/50
# 163/163 [==============================] - 2s 12ms/step - loss: 22.7032 - mae: 2.7352
# Epoch 9/50
# 163/163 [==============================] - 2s 12ms/step - loss: 19.9842 - mae: 2.5828
# Epoch 10/50
# 163/163 [==============================] - 2s 12ms/step - loss: 18.5722 - mae: 2.4733
# Epoch 11/50
# 163/163 [==============================] - 2s 13ms/step - loss: 16.6982 - mae: 2.3301
# Epoch 12/50
# 163/163 [==============================] - 2s 13ms/step - loss: 14.9672 - mae: 2.1981
# Epoch 13/50
# 163/163 [==============================] - 2s 13ms/step - loss: 14.2581 - mae: 2.1478
# Epoch 14/50
# 163/163 [==============================] - 2s 13ms/step - loss: 13.7084 - mae: 2.0983
# Epoch 15/50
# 163/163 [==============================] - 2s 12ms/step - loss: 13.5593 - mae: 2.0827
# Epoch 16/50
# 163/163 [==============================] - 2s 13ms/step - loss: 12.8502 - mae: 2.0288
# Epoch 17/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.9692 - mae: 1.9770
# Epoch 18/50
# 163/163 [==============================] - 2s 12ms/step - loss: 11.8418 - mae: 1.9279
# Epoch 19/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.6435 - mae: 1.9187
# Epoch 20/50
# 163/163 [==============================] - 2s 12ms/step - loss: 11.4343 - mae: 1.9033
# Epoch 21/50
# 163/163 [==============================] - 2s 12ms/step - loss: 11.1466 - mae: 1.8733
# Epoch 22/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.5988 - mae: 1.8168
# Epoch 23/50
# 163/163 [==============================] - 2s 15ms/step - loss: 10.9858 - mae: 1.8372
# Epoch 24/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.6112 - mae: 1.8206
# Epoch 25/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.7913 - mae: 1.8209
# Epoch 26/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.3495 - mae: 1.8015
# Epoch 27/50
# 163/163 [==============================] - 2s 12ms/step - loss: 10.2533 - mae: 1.7703
# Epoch 28/50
# 163/163 [==============================] - 2s 12ms/step - loss: 9.9438 - mae: 1.7792
# Epoch 29/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.0010 - mae: 1.7742
# Epoch 30/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.7806 - mae: 1.7658
# Epoch 31/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.6848 - mae: 1.7467
# Epoch 32/50
# 163/163 [==============================] - 2s 12ms/step - loss: 9.3891 - mae: 1.7306
# Epoch 33/50
# 163/163 [==============================] - 2s 12ms/step - loss: 9.0714 - mae: 1.6940
# Epoch 34/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.8568 - mae: 1.7515
# Epoch 35/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.3387 - mae: 1.7240
# Epoch 36/50
# 163/163 [==============================] - 2s 14ms/step - loss: 8.9959 - mae: 1.6939
# Epoch 37/50
# 163/163 [==============================] - 2s 15ms/step - loss: 9.5026 - mae: 1.7129
# Epoch 38/50
# 163/163 [==============================] - 2s 14ms/step - loss: 9.2605 - mae: 1.7080
# Epoch 39/50
# 163/163 [==============================] - 2s 15ms/step - loss: 9.0665 - mae: 1.6931
# Epoch 40/50
# 163/163 [==============================] - 2s 15ms/step - loss: 8.8767 - mae: 1.6796
# Epoch 41/50
# 163/163 [==============================] - 2s 15ms/step - loss: 9.1475 - mae: 1.6788
# Epoch 42/50
# 163/163 [==============================] - 3s 15ms/step - loss: 8.7530 - mae: 1.6638
# Epoch 43/50
# 163/163 [==============================] - 3s 18ms/step - loss: 8.9137 - mae: 1.6778
# Epoch 44/50
# 163/163 [==============================] - 2s 14ms/step - loss: 8.5871 - mae: 1.6656
# Epoch 45/50
# 163/163 [==============================] - 2s 12ms/step - loss: 8.5739 - mae: 1.6517
# Epoch 46/50
# 163/163 [==============================] - 2s 12ms/step - loss: 8.2764 - mae: 1.6328
# Epoch 47/50
# 163/163 [==============================] - 2s 12ms/step - loss: 8.7215 - mae: 1.6643
# Epoch 48/50
# 163/163 [==============================] - 2s 12ms/step - loss: 8.6869 - mae: 1.6543
# Epoch 49/50
# 163/163 [==============================] - 2s 12ms/step - loss: 8.5326 - mae: 1.6420
# Epoch 50/50
# 163/163 [==============================] - 2s 12ms/step - loss: 8.8306 - mae: 1.6547
# 82/82 [==============================] - 0s 3ms/step
# === Kappa Score = 0.9616005476004286===
#
# ***Fold Number 5***
#
# ***Starting Model Training***
# C:\Users\Nasha\AppData\Local\Temp\ipykernel_4852\3801135714.py:33: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   model.init_sims(replace=True)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 1, 300)            721200
#
#  lstm_9 (LSTM)               (None, 64)                93440
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 163/163 [==============================] - 5s 13ms/step - loss: 65.7502 - mae: 4.3844
# Epoch 2/50
# 163/163 [==============================] - 2s 13ms/step - loss: 40.5162 - mae: 3.5778
# Epoch 3/50
# 163/163 [==============================] - 3s 17ms/step - loss: 33.4111 - mae: 3.4116
# Epoch 4/50
# 163/163 [==============================] - 2s 13ms/step - loss: 29.6680 - mae: 3.3168
# Epoch 5/50
# 163/163 [==============================] - 2s 13ms/step - loss: 27.5610 - mae: 3.1551
# Epoch 6/50
# 163/163 [==============================] - 2s 14ms/step - loss: 25.7719 - mae: 2.9918
# Epoch 7/50
# 163/163 [==============================] - 3s 16ms/step - loss: 23.1466 - mae: 2.7633
# Epoch 8/50
# 163/163 [==============================] - 2s 15ms/step - loss: 20.3270 - mae: 2.5745
# Epoch 9/50
# 163/163 [==============================] - 3s 17ms/step - loss: 17.9245 - mae: 2.4132
# Epoch 10/50
# 163/163 [==============================] - 3s 16ms/step - loss: 16.6254 - mae: 2.3177
# Epoch 11/50
# 163/163 [==============================] - 2s 12ms/step - loss: 14.8704 - mae: 2.2027
# Epoch 12/50
# 163/163 [==============================] - 2s 14ms/step - loss: 14.4558 - mae: 2.1704
# Epoch 13/50
# 163/163 [==============================] - 2s 13ms/step - loss: 14.3954 - mae: 2.1224
# Epoch 14/50
# 163/163 [==============================] - 2s 13ms/step - loss: 13.1281 - mae: 2.0689
# Epoch 15/50
# 163/163 [==============================] - 2s 13ms/step - loss: 12.3423 - mae: 2.0062
# Epoch 16/50
# 163/163 [==============================] - 2s 13ms/step - loss: 12.9850 - mae: 2.0240
# Epoch 17/50
# 163/163 [==============================] - 2s 13ms/step - loss: 12.0969 - mae: 1.9686
# Epoch 18/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.8180 - mae: 1.9404
# Epoch 19/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.4225 - mae: 1.9004
# Epoch 20/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.2281 - mae: 1.8568
# Epoch 21/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.5588 - mae: 1.8220
# Epoch 22/50
# 163/163 [==============================] - 2s 13ms/step - loss: 11.2795 - mae: 1.8493
# Epoch 23/50
# 163/163 [==============================] - 2s 12ms/step - loss: 10.5388 - mae: 1.8109
# Epoch 24/50
# 163/163 [==============================] - 2s 12ms/step - loss: 10.3125 - mae: 1.7708
# Epoch 25/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.2900 - mae: 1.7794
# Epoch 26/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.9480 - mae: 1.7656
# Epoch 27/50
# 163/163 [==============================] - 2s 13ms/step - loss: 10.0271 - mae: 1.7541
# Epoch 28/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.4610 - mae: 1.7212
# Epoch 29/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.7884 - mae: 1.7532
# Epoch 30/50
# 163/163 [==============================] - 2s 15ms/step - loss: 9.3419 - mae: 1.7179
# Epoch 31/50
# 163/163 [==============================] - 2s 15ms/step - loss: 9.7961 - mae: 1.7321
# Epoch 32/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.4656 - mae: 1.7291
# Epoch 33/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.1920 - mae: 1.7063
# Epoch 34/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.8896 - mae: 1.6955
# Epoch 35/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.7647 - mae: 1.6719
# Epoch 36/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.6497 - mae: 1.7202
# Epoch 37/50
# 163/163 [==============================] - 2s 13ms/step - loss: 9.2530 - mae: 1.6950
# Epoch 38/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.7318 - mae: 1.6727
# Epoch 39/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.5312 - mae: 1.6559
# Epoch 40/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.8063 - mae: 1.6732
# Epoch 41/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.6816 - mae: 1.6493
# Epoch 42/50
# 163/163 [==============================] - 2s 14ms/step - loss: 8.8152 - mae: 1.6669
# Epoch 43/50
# 163/163 [==============================] - 2s 14ms/step - loss: 8.5761 - mae: 1.6483
# Epoch 44/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.7528 - mae: 1.6653
# Epoch 45/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.8519 - mae: 1.6492
# Epoch 46/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.6529 - mae: 1.6371
# Epoch 47/50
# 163/163 [==============================] - 2s 13ms/step - loss: 7.6741 - mae: 1.5823
# Epoch 48/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.2142 - mae: 1.6134
# Epoch 49/50
# 163/163 [==============================] - 2s 13ms/step - loss: 7.9650 - mae: 1.6019
# Epoch 50/50
# 163/163 [==============================] - 2s 13ms/step - loss: 8.4457 - mae: 1.6132
# 82/82 [==============================] - 1s 3ms/step
# === Kappa Score = 0.9622725548661694===

# %% [markdown]
# The final kappa score achieved was 0.962
